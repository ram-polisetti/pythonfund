# %%
import pandas as pd

# %%
record1 = pd.Series({'Name': 'Alice',
                    'Class': 'Physics',
                    'Score': 85})
record2 = pd.Series({'Name': 'Jack',
                    'Class': 'Chemistry',
                    'Score': 82})
record3 = pd.Series({'Name': 'Helen',
                    'Class': 'Biology',
                    'Score': 90})

# %%
df = pd.DataFrame([record1, record2, record3], index=['School1', 'School2', 'School1'])
df
# Out:
#           Name      Class  Score
# School1  Alice    Physics     85
# School2   Jack  Chemistry     82
# School1  Helen    Biology     90

# %%
students = [{'Name': 'Alice',
                    'Class': 'Physics',
                    'Score': 85}, 
                    {'Name': 'Jack',
                    'Class': 'Chemistry',
                    'Score': 82},
                    {'Name': 'Helen',
                    'Class': 'Biology',
                    'Score': 90}]

# %%
pd.DataFrame(students, index=['School1', 'School2', 'School3'])
# Out:
#           Name      Class  Score
# School1  Alice    Physics     85
# School2   Jack  Chemistry     82
# School3  Helen    Biology     90

# %%
df.loc['School2']
# Out:
# Name          Jack
# Class    Chemistry
# Score           82
# Name: School2, dtype: object

# %%
df.iloc[1, 2]
# Out:
# 82

# %%
type(df.loc['School1'])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0, :]
# Out:
# Name       Alice
# Class    Physics
# Score         85
# Name: School1, dtype: object

# %%
df.loc['School1', :]
# Out:
#           Name    Class  Score
# School1  Alice  Physics     85
# School1  Helen  Biology     90

# %%
df.loc['School1', 'Name'], df.loc['School1']['Name']
# Out:
# (School1    Alice
#  School1    Helen
#  Name: Name, dtype: object,
#  School1    Alice
#  School1    Helen
#  Name: Name, dtype: object)

# %%
df.T
# Out:
#        School1    School2  School1
# Name     Alice       Jack    Helen
# Class  Physics  Chemistry  Biology
# Score       85         82       90

# %%
df.T.loc['Name']
# Out:
# School1    Alice
# School2     Jack
# School1    Helen
# Name: Name, dtype: object

# %%
df = pd.read_csv("D:\Data Science\Datasets\spreadsheets\csv\Population, Latin and Caribbean Countries, 2010-2019.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of            Series Name  Series Code         Country Name Country Code  \
# 0    Population, total  SP.POP.TOTL  Antigua and Barbuda          ATG
# 1    Population, total  SP.POP.TOTL            Argentina          ARG
# 2    Population, total  SP.POP.TOTL                Aruba          ABW
# 3    Population, total  SP.POP.TOTL         Bahamas, The          BHS
# 4    Population, total  SP.POP.TOTL             Barbados          BRB
# ..                 ...          ...                  ...          ...
# 994                NaN          NaN                  NaN          NaN
# 995                NaN          NaN                  NaN          NaN
# 996                NaN          NaN                  NaN          NaN
# 997                NaN          NaN                  NaN          NaN
# 998                NaN          NaN                  NaN          NaN
#
#      2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# ...

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
dfn = df[['Series Code', 'Country Name', 'Country Code', '2010 [YR2010]',
       '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
       '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]',
       '2019 [YR2019]']].copy()

# %%
dfn.head()
# Out:
#    Series Code         Country Name Country Code  2010 [YR2010]  \
# 0  SP.POP.TOTL  Antigua and Barbuda          ATG        88028.0
# 1  SP.POP.TOTL            Argentina          ARG     40788453.0
# 2  SP.POP.TOTL                Aruba          ABW       101669.0
# 3  SP.POP.TOTL         Bahamas, The          BHS       354942.0
# 4  SP.POP.TOTL             Barbados          BRB       282131.0
#
#    2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# 0        89253.0        90409.0        91516.0        92562.0        93566.0
# 1     41261490.0     41733271.0     42202935.0     42669500.0     43131966.0
# 2       102046.0       102560.0       103159.0       103774.0       104341.0
# 3       359577.0       363584.0       367168.0       370633.0       374206.0
# 4       282987.0       283700.0       284296.0       284825.0       285324.0
#
#    2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]
# ...

# %%
dfn.columns
# Out:
# Index(['Series Code', 'Country Name', 'Country Code', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]',
#        '2019 [YR2019]'],
#       dtype='object')

# %%
dfn.columns = ['Series Code', 'Country Name', 'Country Code', '2010',
       '2011', '2012', '2013', '2014',
       '2015', '2016', '2017', '2018',
       '2019']

# %%
dfn.columns
# Out:
# Index(['Series Code', 'Country Name', 'Country Code', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
dfn.head()
# Out:
#    Series Code         Country Name Country Code        2010        2011  \
# 0  SP.POP.TOTL  Antigua and Barbuda          ATG     88028.0     89253.0
# 1  SP.POP.TOTL            Argentina          ARG  40788453.0  41261490.0
# 2  SP.POP.TOTL                Aruba          ABW    101669.0    102046.0
# 3  SP.POP.TOTL         Bahamas, The          BHS    354942.0    359577.0
# 4  SP.POP.TOTL             Barbados          BRB    282131.0    282987.0
#
#          2012        2013        2014        2015        2016        2017  \
# 0     90409.0     91516.0     92562.0     93566.0     94527.0     95426.0
# 1  41733271.0  42202935.0  42669500.0  43131966.0  43590368.0  44044811.0
# 2    102560.0    103159.0    103774.0    104341.0    104872.0    105366.0
# 3    363584.0    367168.0    370633.0    374206.0    377931.0    381761.0
# 4    283700.0    284296.0    284825.0    285324.0    285796.0    286233.0
#
#          2018        2019
# 0     96286.0     97118.0
# 1  44494502.0  44938712.0
# ...

# %%
dfn = dfn.rename(mapper=str.strip, axis = 'columns')

# %%
cols = list(dfn.columns)
cols
# Out:
# ['Series Code',
#  'Country Name',
#  'Country Code',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019']

# %%
cols = [x.lower().strip().replace(" ", "_") for x in cols]

# %%
dfn.columns = pd.Series(cols)

# %%
dfn.columns
# Out:
# Index(['series_code', 'country_name', 'country_code', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
dfn['series_code']
# Out:
# 0      SP.POP.TOTL
# 1      SP.POP.TOTL
# 2      SP.POP.TOTL
# 3      SP.POP.TOTL
# 4      SP.POP.TOTL
#           ...
# 994            NaN
# 995            NaN
# 996            NaN
# 997            NaN
# 998            NaN
# Name: series_code, Length: 999, dtype: object

# %%
dfn.iloc[41:, :]
# Out:
#      series_code           country_name country_code      2010      2011  \
# 41   SP.POP.TOTL  Virgin Islands (U.S.)          VIR  108358.0  108292.0
# 42           NaN                    NaN          NaN       NaN       NaN
# 43           NaN                    NaN          NaN       NaN       NaN
# 44           NaN                    NaN          NaN       NaN       NaN
# 45           NaN                    NaN          NaN       NaN       NaN
# ..           ...                    ...          ...       ...       ...
# 994          NaN                    NaN          NaN       NaN       NaN
# 995          NaN                    NaN          NaN       NaN       NaN
# 996          NaN                    NaN          NaN       NaN       NaN
# 997          NaN                    NaN          NaN       NaN       NaN
# 998          NaN                    NaN          NaN       NaN       NaN
#
#          2012      2013      2014      2015      2016      2017      2018  \
# ...

# %%
dfn.dropna(axis=0, how='all', inplace=True)

# %%
len(dfn.series_code)
# Out:
# 42

# %%
dfn.tail()
# Out:
#     series_code              country_name country_code        2010  \
# 37  SP.POP.TOTL       Trinidad and Tobago          TTO   1328147.0
# 38  SP.POP.TOTL  Turks and Caicos Islands          TCA     32660.0
# 39  SP.POP.TOTL                   Uruguay          URY   3359275.0
# 40  SP.POP.TOTL             Venezuela, RB          VEN  28439940.0
# 41  SP.POP.TOTL     Virgin Islands (U.S.)          VIR    108358.0
#
#           2011        2012        2013        2014        2015        2016  \
# 37   1336178.0   1344817.0   1353700.0   1362342.0   1370328.0   1377564.0
# 38     33377.0     34066.0     34731.0     35369.0     35981.0     36559.0
# 39   3368934.0   3378974.0   3389439.0   3400434.0   3412009.0   3424132.0
# 40  28888369.0  29362449.0  29783571.0  30045134.0  30081829.0  29846179.0
# 41    108292.0    108191.0    108044.0    107884.0    107710.0    107510.0
#
#           2017        2018        2019
# 37   1384072.0   1389858.0   1394973.0
# ...

# %%
dfn['series_code'].value_counts()
# Out:
# SP.POP.TOTL    42
# Name: series_code, dtype: int64

# %%
final_df = dfn.drop(['series_code'], axis=1)

# %%
final_df.columns
# Out:
# Index(['country_name', 'country_code', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
dfn[dfn['2010']> 405000]
# Out:
#     series_code         country_name country_code         2010         2011  \
# 1   SP.POP.TOTL            Argentina          ARG   40788453.0   41261490.0
# 6   SP.POP.TOTL              Bolivia          BOL   10048590.0   10212954.0
# 7   SP.POP.TOTL               Brazil          BRA  195713635.0  197514534.0
# 10  SP.POP.TOTL                Chile          CHL   17062536.0   17233576.0
# 11  SP.POP.TOTL             Colombia          COL   45222700.0   45663099.0
# 12  SP.POP.TOTL           Costa Rica          CRI    4577378.0    4633086.0
# 13  SP.POP.TOTL                 Cuba          CUB   11225832.0   11236670.0
# 16  SP.POP.TOTL   Dominican Republic          DOM    9695121.0    9813210.0
# 17  SP.POP.TOTL              Ecuador          ECU   15011117.0   15243883.0
# 18  SP.POP.TOTL          El Salvador          SLV    6183875.0    6210568.0
# 20  SP.POP.TOTL            Guatemala          GTM   14259687.0   14521515.0
# ...

# %% [markdown]
# # Testing Git and VSCode sync

# %%
import numpy as np
import pandas as pd

# %%
a = np.arange(1, 1000, 1.5).reshape(9, -1)

# %%
a
# Out:
# array([[  1. ,   2.5,   4. ,   5.5,   7. ,   8.5,  10. ,  11.5,  13. ,
#          14.5,  16. ,  17.5,  19. ,  20.5,  22. ,  23.5,  25. ,  26.5,
#          28. ,  29.5,  31. ,  32.5,  34. ,  35.5,  37. ,  38.5,  40. ,
#          41.5,  43. ,  44.5,  46. ,  47.5,  49. ,  50.5,  52. ,  53.5,
#          55. ,  56.5,  58. ,  59.5,  61. ,  62.5,  64. ,  65.5,  67. ,
#          68.5,  70. ,  71.5,  73. ,  74.5,  76. ,  77.5,  79. ,  80.5,
#          82. ,  83.5,  85. ,  86.5,  88. ,  89.5,  91. ,  92.5,  94. ,
#          95.5,  97. ,  98.5, 100. , 101.5, 103. , 104.5, 106. , 107.5,
#         109. , 110.5],
#        [112. , 113.5, 115. , 116.5, 118. , 119.5, 121. , 122.5, 124. ,
#         125.5, 127. , 128.5, 130. , 131.5, 133. , 134.5, 136. , 137.5,
#         139. , 140.5, 142. , 143.5, 145. , 146.5, 148. , 149.5, 151. ,
#         152.5, 154. , 155.5, 157. , 158.5, 160. , 161.5, 163. , 164.5,
#         166. , 167.5, 169. , 170.5, 172. , 173.5, 175. , 176.5, 178. ,
# ...
